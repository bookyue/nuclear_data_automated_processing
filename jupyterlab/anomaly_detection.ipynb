# %% [markdown]
# # Getting The Data

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from nuc_data_tool.db.fetch_data import fetch_files_by_name, fetch_data_by_filename_and_physical_quantities
files = fetch_files_by_name()

# %%
import pandas as pd

nuc_data = pd.DataFrame()

for file in files:
    dict_nuc_data = fetch_data_by_filename_and_physical_quantities(file, 'isotope', True)

    for pq in dict_nuc_data:
        if dict_nuc_data[pq].empty:
            continue

        nuc_data = nuc_data.append(dict_nuc_data[pq], ignore_index=True)

nuc_data.info
# Out:
# <bound method DataFrame.info of          nuc_ix     name first_step last_step      middle_step_1  \
# 0         10010       H1          0         0  0.000004646090694
# 1         10020       H2          0         0  0.000002187007232
# 2         10030       H3          0         0   0.00002829193536
# 3         10040       H4          0         0               0E-9
# 4         10050       H5          0         0               0E-9
# ...         ...      ...        ...       ...                ...
# 362990  1102720    Ds272          0         0               0E-9
# 362991  1102730    Ds273          0         0               0E-9
# 362992  1102791  Ds279m1          0         0               0E-9
# 362993  1112720    Rg272          0         0               0E-9
# 362994  1112990   Pseudo          0         0               0E-9
#
#             middle_step_2      middle_step_3      middle_step_4  \
# 0       0.000009344544900   0.00001410187475   0.00001891756544
# 1       0.000004388726293  0.000006607321145  0.000008842630832
# 2        0.00005667838403   0.00008518316066    0.0001138057392
# 3                    0E-9               0E-9               0E-9
# 4                    0E-9               0E-9               0E-9
# ...                   ...                ...                ...
# 362990               0E-9               0E-9               0E-9
# 362991               0E-9               0E-9               0E-9
# 362992               0E-9               0E-9               0E-9
# 362993               0E-9               0E-9               0E-9
# 362994               0E-9               0E-9               0E-9
#
#            middle_step_5     middle_step_6  ... middle_step_182  \
# 0       0.00002379071329  0.00002872040805  ...             NaN
# 1       0.00001109436650  0.00001336223707  ...             NaN
# 2        0.0001425441966   0.0001713965614  ...             NaN
# 3                   0E-9              0E-9  ...             NaN
# 4                   0E-9              0E-9  ...             NaN
# ...                  ...               ...  ...             ...
# 362990              0E-9              0E-9  ...             NaN
# 362991              0E-9              0E-9  ...             NaN
# 362992              0E-9              0E-9  ...             NaN
# 362993              0E-9              0E-9  ...             NaN
# 362994              0E-9              0E-9  ...             NaN
#
#        middle_step_183 middle_step_184 middle_step_185 middle_step_186  \
# 0                  NaN             NaN             NaN             NaN
# 1                  NaN             NaN             NaN             NaN
# 2                  NaN             NaN             NaN             NaN
# 3                  NaN             NaN             NaN             NaN
# 4                  NaN             NaN             NaN             NaN
# ...                ...             ...             ...             ...
# 362990             NaN             NaN             NaN             NaN
# 362991             NaN             NaN             NaN             NaN
# 362992             NaN             NaN             NaN             NaN
# 362993             NaN             NaN             NaN             NaN
# 362994             NaN             NaN             NaN             NaN
#
#        middle_step_187 middle_step_188 middle_step_189 middle_step_190  \
# 0                  NaN             NaN             NaN             NaN
# 1                  NaN             NaN             NaN             NaN
# 2                  NaN             NaN             NaN             NaN
# 3                  NaN             NaN             NaN             NaN
# 4                  NaN             NaN             NaN             NaN
# ...                ...             ...             ...             ...
# 362990             NaN             NaN             NaN             NaN
# 362991             NaN             NaN             NaN             NaN
# 362992             NaN             NaN             NaN             NaN
# 362993             NaN             NaN             NaN             NaN
# 362994             NaN             NaN             NaN             NaN
#
#        middle_step_191
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 362990             NaN
# 362991             NaN
# 362992             NaN
# 362993             NaN
# 362994             NaN
#
# [362995 rows x 195 columns]>

# %% [markdown]
# # Setting up Environment

# %%
unnecessary_columns = ['nuc_ix', 'name']
numeric_columns = [col for col in nuc_data.columns.tolist() if col not in unnecessary_columns]

# %%
from pycaret.anomaly import *

exp_ano = setup(nuc_data, normalize = True, 
                normalize_method='robust',
                ignore_features = unnecessary_columns,
                numeric_features = numeric_columns,
                session_id = 123)
# Out:
# <style  type="text/css" >
# #T_73c3a_row2_col1,#T_73c3a_row21_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_73c3a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73c3a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_73c3a_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_73c3a_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_73c3a_row1_col0" class="data row1 col0" >Original Data</td>
#                         <td id="T_73c3a_row1_col1" class="data row1 col1" >(362995, 195)</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_73c3a_row2_col0" class="data row2 col0" >Missing Values</td>
#                         <td id="T_73c3a_row2_col1" class="data row2 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_73c3a_row3_col0" class="data row3 col0" >Numeric Features</td>
#                         <td id="T_73c3a_row3_col1" class="data row3 col1" >193</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_73c3a_row4_col0" class="data row4 col0" >Categorical Features</td>
#                         <td id="T_73c3a_row4_col1" class="data row4 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_73c3a_row5_col0" class="data row5 col0" >Ordinal Features</td>
#                         <td id="T_73c3a_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_73c3a_row6_col0" class="data row6 col0" >High Cardinality Features</td>
#                         <td id="T_73c3a_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_73c3a_row7_col0" class="data row7 col0" >High Cardinality Method</td>
#                         <td id="T_73c3a_row7_col1" class="data row7 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_73c3a_row8_col0" class="data row8 col0" >Transformed Data</td>
#                         <td id="T_73c3a_row8_col1" class="data row8 col1" >(362995, 193)</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_73c3a_row9_col0" class="data row9 col0" >CPU Jobs</td>
#                         <td id="T_73c3a_row9_col1" class="data row9 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_73c3a_row10_col0" class="data row10 col0" >Use GPU</td>
#                         <td id="T_73c3a_row10_col1" class="data row10 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_73c3a_row11_col0" class="data row11 col0" >Log Experiment</td>
#                         <td id="T_73c3a_row11_col1" class="data row11 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_73c3a_row12_col0" class="data row12 col0" >Experiment Name</td>
#                         <td id="T_73c3a_row12_col1" class="data row12 col1" >anomaly-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_73c3a_row13_col0" class="data row13 col0" >USI</td>
#                         <td id="T_73c3a_row13_col1" class="data row13 col1" >4688</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_73c3a_row14_col0" class="data row14 col0" >Imputation Type</td>
#                         <td id="T_73c3a_row14_col1" class="data row14 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_73c3a_row15_col0" class="data row15 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_73c3a_row15_col1" class="data row15 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_73c3a_row16_col0" class="data row16 col0" >Numeric Imputer</td>
#                         <td id="T_73c3a_row16_col1" class="data row16 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_73c3a_row17_col0" class="data row17 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_73c3a_row17_col1" class="data row17 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_73c3a_row18_col0" class="data row18 col0" >Categorical Imputer</td>
#                         <td id="T_73c3a_row18_col1" class="data row18 col1" >mode</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_73c3a_row19_col0" class="data row19 col0" >Iterative Imputation Categorical Model</td>
#                         <td id="T_73c3a_row19_col1" class="data row19 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_73c3a_row20_col0" class="data row20 col0" >Unknown Categoricals Handling</td>
#                         <td id="T_73c3a_row20_col1" class="data row20 col1" >least_frequent</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_73c3a_row21_col0" class="data row21 col0" >Normalize</td>
#                         <td id="T_73c3a_row21_col1" class="data row21 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_73c3a_row22_col0" class="data row22 col0" >Normalize Method</td>
#                         <td id="T_73c3a_row22_col1" class="data row22 col1" >robust</td>
#             </tr>
#             <tr>
#                         <th id="T_73c3a_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_73c3a_row23_col0" class="data row23 col0" >Transformation</td>
#                         <td id="T_73c3a_row23_col1" class="data row23 col1" >False</td>
#             </tr>
#             <tr>

# %% [markdown]
# # Create a Model

# %%
iforest = create_model('iforest', n_jobs=-1, fraction=0.01, n_estimators=256)

# %%
iforest
# Out:
# IForest(behaviour='new', bootstrap=False, contamination=0.01,
#     max_features=1.0, max_samples='auto', n_estimators=256, n_jobs=-1,
#     random_state=123, verbose=0)

# %% [markdown]
# # Assign a Model

# %%
iforest_results = assign_model(iforest)

# %%
iforest_results.head()
# Out:
#    nuc_ix name first_step last_step      middle_step_1      middle_step_2  \
# 0   10010   H1          0         0  0.000004646090694  0.000009344544900
# 1   10020   H2          0         0  0.000002187007232  0.000004388726293
# 2   10030   H3          0         0   0.00002829193536   0.00005667838403
# 3   10040   H4          0         0               0E-9               0E-9
# 4   10050   H5          0         0               0E-9               0E-9
#
#        middle_step_3      middle_step_4     middle_step_5     middle_step_6  \
# 0   0.00001410187475   0.00001891756544  0.00002379071329  0.00002872040805
# 1  0.000006607321145  0.000008842630832  0.00001109436650  0.00001336223707
# 2   0.00008518316066    0.0001138057392   0.0001425441966   0.0001713965614
# 3               0E-9               0E-9              0E-9              0E-9
# 4               0E-9               0E-9              0E-9              0E-9
#
#    ... middle_step_184 middle_step_185 middle_step_186 middle_step_187  \
# 0  ...             NaN             NaN             NaN             NaN
# 1  ...             NaN             NaN             NaN             NaN
# 2  ...             NaN             NaN             NaN             NaN
# 3  ...             NaN             NaN             NaN             NaN
# 4  ...             NaN             NaN             NaN             NaN
#
#   middle_step_188 middle_step_189 middle_step_190 middle_step_191 Anomaly  \
# 0             NaN             NaN             NaN             NaN       0
# 1             NaN             NaN             NaN             NaN       0
# 2             NaN             NaN             NaN             NaN       0
# 3             NaN             NaN             NaN             NaN       0
# 4             NaN             NaN             NaN             NaN       0
#
#   Anomaly_Score
# 0     -0.029097
# 1     -0.031314
# 2     -0.026371
# 3     -0.124191
# 4     -0.124191
#
# [5 rows x 197 columns]

# %%
iforest_results[iforest_results.Anomaly == 1]
# Out:
#         nuc_ix   name first_step last_step      middle_step_1  \
# 11179   932390  Np239          0         0    0.0004829907170
# 18821   932390  Np239          0         0    0.0004929492885
# 22642   932390  Np239          0         0    0.0004879700028
# 26463   932390  Np239          0         0    0.0004829907170
# 30262   922360   U236          0         0    0.0003154730051
# ...        ...    ...        ...       ...                ...
# 361299  621520  Sm152          0         0    0.0007262910292
# 361345  631530  Eu153          0         0   0.00006771642981
# 362709  932370  Np237          0         0   0.00004979919478
# 362732  942400  Pu240          0         0    0.0002761976058
# 362733  942410  Pu241          0         0  0.000001689593538
#
#            middle_step_2     middle_step_3    middle_step_4    middle_step_5  \
# 11179     0.001311923535    0.002190465713   0.003068430559   0.003937409398
# 18821     0.001338973505    0.002235629955   0.003131697168   0.004018593097
# 22642     0.001325448520    0.002213047834   0.003100063863   0.003978001248
# 26463     0.001311923535    0.002190465713   0.003068430559   0.003937409398
# 30262    0.0006309399849   0.0009464009394   0.001261855869   0.001577304773
# ...                  ...               ...              ...              ...
# 361299    0.001486931129    0.002283499545   0.003122343011   0.004006200929
# 361345   0.0002443811383   0.0004981644975  0.0008076552284   0.001158506468
# 362709   0.0001947034536   0.0004284677625  0.0007454535286   0.001140567295
# 362732    0.001227239278    0.002933588468   0.005446482148   0.008795989920
# 362733  0.00001508770290  0.00005394475835  0.0001331044755  0.0002680153267
#
#           middle_step_6  ... middle_step_184 middle_step_185 middle_step_186  \
# 11179    0.004796083377  ...             NaN             NaN             NaN
# 18821    0.004894971694  ...             NaN             NaN             NaN
# 22642    0.004845527536  ...             NaN             NaN             NaN
# 26463    0.004796083377  ...             NaN             NaN             NaN
# 30262    0.001892747653  ...             NaN             NaN             NaN
# ...                 ...  ...             ...             ...             ...
# 361299   0.004935781313  ...             NaN             NaN             NaN
# 361345   0.001541158355  ...             NaN             NaN             NaN
# 362709   0.001609205661  ...             NaN             NaN             NaN
# 362732    0.01299642242  ...             NaN             NaN             NaN
# 362733  0.0004743676401  ...             NaN             NaN             NaN
#
#        middle_step_187 middle_step_188 middle_step_189 middle_step_190  \
# 11179              NaN             NaN             NaN             NaN
# 18821              NaN             NaN             NaN             NaN
# 22642              NaN             NaN             NaN             NaN
# 26463              NaN             NaN             NaN             NaN
# 30262              NaN             NaN             NaN             NaN
# ...                ...             ...             ...             ...
# 361299             NaN             NaN             NaN             NaN
# 361345             NaN             NaN             NaN             NaN
# 362709             NaN             NaN             NaN             NaN
# 362732             NaN             NaN             NaN             NaN
# 362733             NaN             NaN             NaN             NaN
#
#        middle_step_191 Anomaly Anomaly_Score
# 11179              NaN       1      0.006412
# 18821              NaN       1      0.006412
# 22642              NaN       1      0.006412
# 26463              NaN       1      0.006412
# 30262              NaN       1      0.000507
# ...                ...     ...           ...
# 361299             NaN       1      0.020330
# 361345             NaN       1      0.012146
# 362709             NaN       1      0.023099
# 362732             NaN       1      0.024707
# 362733             NaN       1      0.019538
#
# [3613 rows x 197 columns]

# %%
iforest_results[iforest_results.Anomaly == 1]["nuc_ix"].T.nunique()
# Out:
# 208

# %% [markdown]
# # Plot a Model

# %%
plot_model(iforest)

# %%
plot_model(iforest, plot = 'umap')

# %% [markdown]
# # Saving the Model

# %%
save_model(iforest,'nuc_all_steps_isotope_iforest_0.01_model')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['nuc_ix', 'name'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['first_step',
#                                                            'last_step',
#                                                            'middle_step_1',
#                                                            'middle_step_2',
#                                                            'middle_step_3',
#                                                            'middle_step_4',
#                                                            'middle_step_5',
#                                                            'middle_step_6',
#                                                            'middle_step_7',
#                                                            'middle_step_8',
#                                                            'mi...
#                  ('fix_perfect', 'passthrough'),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   IForest(behaviour='new', bootstrap=False, contamination=0.01,
#      max_features=1.0, max_samples='auto', n_estimators=256, n_jobs=-1,
#      random_state=123, verbose=0)]],
#           verbose=False),
#  'nuc_all_steps_isotope_iforest_0.01_model.pkl')

# %% [markdown]
# # Predict on Unseen Data

# %%
predictions = predict_model(iforest, data=nuc_data)

# %%
predictions.head()

# %%
predictions[predictions.Anomaly == 1]

# %% [markdown]
# # Loading the Saved Model

# %%
from pycaret.anomaly import *
saved_iforest = load_model('nuc_all_steps_isotope_model')

# %%
new_prediction = predict_model(saved_iforest, data=nuc_data)

# %%
new_prediction.head()

# %%
new_prediction[new_prediction.Label == 1]
